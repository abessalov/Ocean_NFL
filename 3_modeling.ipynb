# %% [markdown]
# ### Functions

# %%
def get_datasets(df, feat_target, feat_norm, norm_shift, flg_ma):
    season_min = 2023
    # calculate mean and std
    eps = 1e-3
    feats_static = [
        'static_height_cm',
        'static_weight_kg',
        'static_bmi_calc',
    ]
    if feat_norm != None:
        df_ag = df.groupby(feat_norm)[feat_target].agg([np.mean, np.std]).fillna(0)
        df_ag.columns = ['m','s']
        df_ag.reset_index(inplace = True)
        # create lag -1 to prevent look into the future
        df_ag['season'] = df_ag['season'] + norm_shift
        df_ag['s'] = df_ag['s'] + eps
        df = df.merge(df_ag, how = 'left')
        
        # normalize static features
        for f in feats_static:
            df[f] = (df[f] - df[f].mean()) / df[f].std()
    else:
        df['m'] = 0
        df['s']  = 1 + eps

    # normalization of target
    df['target'] = (df[feat_target] - df['m']) / df['s'] 

    # create lag features of the target
    max_lag = season_min - 2016
    for i in range(1,max_lag):
        df[f'lag{i}'] = df.groupby('player_id')['target'].shift(i)
    feats_lag = [f'lag{i}' for i in range(1, max_lag)]

    # feats for training
    feats_used = feats_static + feats_lag

    # moving averages features
    if flg_ma:
        for i in range(1,max_lag):
            df[f'ma{i}'] = df.loc[:,'lag1':f'lag{i}'].mean(axis = 1)
        feats_ma = [f'ma{i}' for i in range(1, max_lag)]
        feats_used = feats_used + feats_ma

    # nulls filling (for sklearn models)
    for f in feats_lag:
        df[f] = df[f].fillna(-1)

    # filtering
    filt = df.season >= season_min
    feats_info = ['player_id','display_name','season','position','fantasy_points_ppr','games','fantasy_points_per_game']
    return df[filt][feats_used], df[filt]['target'], df[filt]['m'], df[filt]['s'], df[filt][feats_info]

# %%
# utility function to get kfold avg and std scores
def cv_scores(clf, kfold):
    pred = ms.cross_val_predict(clf, x, y, cv = kfold)
    pred = (pred * s + m).values
    list_res = list()
    for cv in kfold.split(real):
        ind = list(cv[1])
        list_res.append(metrics.mean_absolute_error(pred[ind], real[ind]))
    return np.mean(list_res), np.std(list_res)


def model_searching(kfold1, kfold2):
    dict_out = dict()
    dict_params = dict()
    
    ###
    modelname = 'Decision tree'
    from sklearn.tree import DecisionTreeRegressor
    clf = DecisionTreeRegressor()
    params = {
        'max_depth': list(range(2,10)),
    }
    grid = ms.GridSearchCV(clf, params, cv = kfold1, scoring = 'neg_mean_absolute_error')
    grid.fit(x, y)
    clf = DecisionTreeRegressor(**grid.best_params_)
    dict_out[modelname] = cv_scores(clf = clf, kfold = kfold2)
    dict_params[modelname] = str(grid.best_params_)
    
    ###
    modelname = 'Xgboost'
    import xgboost as xgb
    clf = xgb.XGBRegressor()
    params = {
        'learning_rate': [0.05, 0.1],
        'n_estimators': [50, 100, 200],
        'max_depth': [3, 6, 9],
        'gamma': [0, 1],
        'subsample': [0.7, 1],
        'colsample_bytree': [0.7, 1]
    }
    grid = ms.GridSearchCV(clf, params, cv = kfold1, scoring = 'neg_mean_absolute_error')
    grid.fit(x, y)
    clf = xgb.XGBRegressor(**grid.best_params_)
    dict_out[modelname] = cv_scores(clf = clf, kfold = kfold2)
    dict_params[modelname] = str(grid.best_params_)
    
    ###
    modelname = 'Random forest'
    from sklearn.ensemble import RandomForestRegressor
    clf = RandomForestRegressor(n_estimators=100)
    params = {
        'max_depth': [3, 6, None],
    }
    grid = ms.GridSearchCV(clf, params, cv = kfold1, scoring = 'neg_mean_absolute_error')
    grid.fit(x, y)
    clf = RandomForestRegressor(**grid.best_params_)
    dict_out[modelname] = cv_scores(clf = clf, kfold = kfold2)
    dict_params[modelname] = str(grid.best_params_)
    
    ###
    modelname = 'KNN'
    from sklearn.neighbors import KNeighborsRegressor
    clf = KNeighborsRegressor(n_neighbors=2)
    params = {
        'n_neighbors': [2, 5, 10, 25, 50],
    }
    grid = ms.GridSearchCV(clf, params, cv = kfold1, scoring = 'neg_mean_absolute_error')
    grid.fit(x, y)
    clf = KNeighborsRegressor(**grid.best_params_)
    dict_out[modelname] = cv_scores(clf = clf, kfold = kfold2)
    dict_params[modelname] = str(grid.best_params_)
    
    ###
    modelname = 'Linear model'
    from sklearn.linear_model import ElasticNet
    clf = ElasticNet(alpha = 0.005)
    params = {
        'alpha': [1, 0.5, 0.1, 0.05, 0.01, 0.005, 0.001],
        'l1_ratio': [10, 2, 1, 0.5, 0.1, 0.01],
    }
    grid = ms.GridSearchCV(clf, params, cv = kfold1, scoring = 'neg_mean_absolute_error')
    grid.fit(x, y)
    clf = ElasticNet(**grid.best_params_)
    dict_out[modelname] = cv_scores(clf = clf, kfold = kfold2)
    dict_params[modelname] = str(grid.best_params_)
    
    ###
    modelname = 'Neural network (MLP)'
    from sklearn.neural_network import MLPRegressor
    clf = MLPRegressor()
    params = {
        'activation' : ['identity', 'logistic', 'tanh', 'relu'],
        'hidden_layer_sizes': [(2,), (4,), (8,), (16,), (2,2), (4,2), (8,2) ],
    }
    grid = ms.GridSearchCV(clf, params, cv = kfold1, scoring = 'neg_mean_absolute_error')
    grid.fit(x, y)
    clf = MLPRegressor(**grid.best_params_)
    dict_out[modelname] = cv_scores(clf = clf, kfold = kfold2)
    dict_params[modelname] = str(grid.best_params_)

    ###
    # moving averages
    if flg_ma:
        for i in range(1,6):
            pred = x[f'ma{i}']
            pred = (pred * s + m).values
            list_res = list()
            for cv in kfold2.split(real):
                ind = list(cv[1])
                list_res.append(metrics.mean_absolute_error(pred[ind], real[ind]))
            dict_out[f'MA{i}'] = np.mean(list_res), np.std(list_res)
        
    return dict_out, dict_params

# %% [markdown]
# ### Training

# %%
# %%time
#####################
# TRAINING
#####################

# The targets we want to predict (comparing "total" vs. "games" * "per game")
feats_target = [
    'games',
    'fantasy_points_per_game',
    'fantasy_points_ppr',
]
# Normalization features
feats_norm = [
    None,                        # without normalization
    ['season'],                  # only season
    ['season','position'],       # by the position + season
    ['season','player_cluster'], # by the player cluster + season
    ['season','team_cluster'],   # by the team cluster + season
]
norm_shift = 1 # number of seasons to shift for normalization, 0 - for the new 2024 predictions, 1 - for training 

########## 
# read main preprocessed dataset
df = pd.read_pickle('data/df_model.pkl')

from sklearn import model_selection as ms
from sklearn import metrics
kfold1 = ms.KFold(n_splits = 5, shuffle = True, random_state = 2017) # k folds for models parameters searching
kfold2 = ms.KFold(n_splits = 5, shuffle = True, random_state = 2022) # k folds for best models evaluation

# main loop
df_out_mean = pd.DataFrame()
df_out_std  = pd.DataFrame()
df_param = pd.DataFrame()
for feat_target in feats_target:
    for feat_norm in feats_norm:
        for flg_ma in [True, False]:
            try:
                print(feat_target, feat_norm, flg_ma)
                # 1) create datasets
                x, y, m, s, df_out = get_datasets(df = df[df.season_len > 1], 
                                          feat_target = feat_target, 
                                          feat_norm = feat_norm, 
                                          norm_shift = norm_shift, 
                                          flg_ma = flg_ma)
                real = (y * s + m).values

                # 2) searching the best models parameters on kfold1 and get their scores on kfold2 
                res1, param1 = model_searching(kfold1, kfold2)

                df_out1 = pd.DataFrame(res1)
                df_out1['target'] = feat_target
                df_out1['norm'] = str(feat_norm)
                df_out1['ma'] = flg_ma
                df_out_mean = pd.concat([df_out_mean, df_out1[:1]])
                df_out_std = pd.concat([df_out_std, df_out1[1:]])
                
                df_out2 = pd.DataFrame([[k,v] for k,v in param1.items()]).set_index(0).T
                df_out2['target'] = feat_target
                df_out2['norm'] = str(feat_norm)
                df_out2['ma'] = flg_ma
                df_param = pd.concat([df_param, df_out2])
                
            except Exception as e:
                print(e)
# Out:
# games None True
# games None False
# games ['season'] True
# games ['season'] False
# games ['season', 'position'] True
# games ['season', 'position'] False
# games ['season', 'player_cluster'] True
# games ['season', 'player_cluster'] False
# games ['season', 'team_cluster'] True
# games ['season', 'team_cluster'] False
# fantasy_points_per_game None True
# fantasy_points_per_game None False
# fantasy_points_per_game ['season'] True
# fantasy_points_per_game ['season'] False
# fantasy_points_per_game ['season', 'position'] True
# fantasy_points_per_game ['season', 'position'] False
# fantasy_points_per_game ['season', 'player_cluster'] True
# fantasy_points_per_game ['season', 'player_cluster'] False
# fantasy_points_per_game ['season', 'team_cluster'] True
# fantasy_points_per_game ['season', 'team_cluster'] False
# fantasy_points_ppr None True
# fantasy_points_ppr None False
# fantasy_points_ppr ['season'] True
# fantasy_points_ppr ['season'] False
# fantasy_points_ppr ['season', 'position'] True
# fantasy_points_ppr ['season', 'position'] False
# fantasy_points_ppr ['season', 'player_cluster'] True
# fantasy_points_ppr ['season', 'player_cluster'] False
# fantasy_points_ppr ['season', 'team_cluster'] True
# fantasy_points_ppr ['season', 'team_cluster'] False
# Wall time: 40min 56s

# %%
print('Average MAE scores')
filt = df_out_mean.target == 'fantasy_points_ppr'
df_out1 = df_out_mean[filt]
del df_out1['target']
display(df_out1.set_index(['norm','ma']).ffill().T.style.background_gradient(cmap='RdYlGn_r').set_precision(1))

print('STD of MAE scores')
filt = df_out_std.target == 'fantasy_points_ppr'
df_out1 = df_out_std[filt]
del df_out1['target']
display(df_out1.set_index(['norm','ma']).ffill().T.style.background_gradient(cmap='RdYlGn_r').set_precision(1))
# Out:
# Average MAE scores
# <style type="text/css">
# #T_15ea9_row0_col0, #T_15ea9_row1_col8 {
#   background-color: #78c565;
#   color: #000000;
# }
# #T_15ea9_row0_col1 {
#   background-color: #e34933;
#   color: #f1f1f1;
# }
# #T_15ea9_row0_col2, #T_15ea9_row0_col5, #T_15ea9_row0_col8, #T_15ea9_row0_col9, #T_15ea9_row5_col0, #T_15ea9_row10_col1, #T_15ea9_row10_col3, #T_15ea9_row10_col4, #T_15ea9_row10_col6, #T_15ea9_row10_col7 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_15ea9_row0_col3, #T_15ea9_row10_col2 {
#   background-color: #c01a27;
#   color: #f1f1f1;
# }
# #T_15ea9_row0_col4 {
#   background-color: #a70226;
#   color: #f1f1f1;
# }
# #T_15ea9_row0_col6, #T_15ea9_row4_col7 {
#   background-color: #026c39;
#   color: #f1f1f1;
# }
# #T_15ea9_row0_col7, #T_15ea9_row2_col6, #T_15ea9_row6_col6, #T_15ea9_row6_col7, #T_15ea9_row7_col6, #T_15ea9_row7_col7, #T_15ea9_row8_col6 {
#   background-color: #016a38;
#   color: #f1f1f1;
# }
# #T_15ea9_row1_col0, #T_15ea9_row1_col6, #T_15ea9_row1_col7, #T_15ea9_row2_col7, #T_15ea9_row3_col6, #T_15ea9_row3_col7, #T_15ea9_row4_col1, #T_15ea9_row4_col2, #T_15ea9_row4_col3, #T_15ea9_row4_col4, #T_15ea9_row4_col5, #T_15ea9_row4_col9, #T_15ea9_row5_col6, #T_15ea9_row5_col7, #T_15ea9_row5_col8, #T_15ea9_row8_col7 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_15ea9_row1_col1 {
#   background-color: #1e9a51;
#   color: #f1f1f1;
# }
# #T_15ea9_row1_col2 {
#   background-color: #2da155;
#   color: #f1f1f1;
# }
# #T_15ea9_row1_col3 {
#   background-color: #7dc765;
#   color: #000000;
# }
# #T_15ea9_row1_col4 {
#   background-color: #f8fcb6;
#   color: #000000;
# }
# #T_15ea9_row1_col5 {
#   background-color: #f5fbb2;
#   color: #000000;
# }
# #T_15ea9_row1_col9, #T_15ea9_row2_col3 {
#   background-color: #cdea83;
#   color: #000000;
# }
# #T_15ea9_row2_col0 {
#   background-color: #118848;
#   color: #f1f1f1;
# }
# #T_15ea9_row2_col1 {
#   background-color: #5db961;
#   color: #f1f1f1;
# }
# #T_15ea9_row2_col2 {
#   background-color: #42ac5a;
#   color: #f1f1f1;
# }
# #T_15ea9_row2_col4 {
#   background-color: #91d068;
#   color: #000000;
# }
# #T_15ea9_row2_col5, #T_15ea9_row8_col0 {
#   background-color: #8ccd67;
#   color: #000000;
# }
# #T_15ea9_row2_col8, #T_15ea9_row9_col0 {
#   background-color: #8ecf67;
#   color: #000000;
# }
# #T_15ea9_row2_col9, #T_15ea9_row5_col9 {
#   background-color: #c3e67d;
#   color: #000000;
# }
# #T_15ea9_row3_col0 {
#   background-color: #0d8044;
#   color: #f1f1f1;
# }
# #T_15ea9_row3_col1 {
#   background-color: #4eb15d;
#   color: #f1f1f1;
# }
# #T_15ea9_row3_col2 {
#   background-color: #097940;
#   color: #f1f1f1;
# }
# #T_15ea9_row3_col3 {
#   background-color: #e75337;
#   color: #f1f1f1;
# }
# #T_15ea9_row3_col4 {
#   background-color: #93d168;
#   color: #000000;
# }
# #T_15ea9_row3_col5, #T_15ea9_row8_col9, #T_15ea9_row10_col0 {
#   background-color: #b5df74;
#   color: #000000;
# }
# #T_15ea9_row3_col8 {
#   background-color: #07753e;
#   color: #f1f1f1;
# }
# #T_15ea9_row3_col9 {
#   background-color: #fbfdba;
#   color: #000000;
# }
# #T_15ea9_row4_col0 {
#   background-color: #0a7b41;
#   color: #f1f1f1;
# }
# #T_15ea9_row4_col6 {
#   background-color: #04703b;
#   color: #f1f1f1;
# }
# #T_15ea9_row4_col8 {
#   background-color: #0e8245;
#   color: #f1f1f1;
# }
# #T_15ea9_row5_col1 {
#   background-color: #82c966;
#   color: #000000;
# }
# #T_15ea9_row5_col2 {
#   background-color: #17934e;
#   color: #f1f1f1;
# }
# #T_15ea9_row5_col3 {
#   background-color: #c1e57b;
#   color: #000000;
# }
# #T_15ea9_row5_col4 {
#   background-color: #0b7d42;
#   color: #f1f1f1;
# }
# #T_15ea9_row5_col5 {
#   background-color: #70c164;
#   color: #000000;
# }
# #T_15ea9_row6_col0, #T_15ea9_row7_col0 {
#   background-color: #89cc67;
#   color: #000000;
# }
# #T_15ea9_row6_col1, #T_15ea9_row9_col4 {
#   background-color: #f67f4b;
#   color: #f1f1f1;
# }
# #T_15ea9_row6_col2 {
#   background-color: #fba05b;
#   color: #000000;
# }
# #T_15ea9_row6_col3 {
#   background-color: #f98e52;
#   color: #f1f1f1;
# }
# #T_15ea9_row6_col4 {
#   background-color: #b50f26;
#   color: #f1f1f1;
# }
# #T_15ea9_row6_col5, #T_15ea9_row10_col8 {
#   background-color: #fff0a6;
#   color: #000000;
# }
# #T_15ea9_row6_col8 {
#   background-color: #eef8a8;
#   color: #000000;
# }
# #T_15ea9_row6_col9 {
#   background-color: #fee999;
#   color: #000000;
# }
# #T_15ea9_row7_col1 {
#   background-color: #f7844e;
#   color: #f1f1f1;
# }
# #T_15ea9_row7_col2 {
#   background-color: #feeda1;
#   color: #000000;
# }
# #T_15ea9_row7_col3 {
#   background-color: #feec9f;
#   color: #000000;
# }
# #T_15ea9_row7_col4 {
#   background-color: #fdad60;
#   color: #000000;
# }
# #T_15ea9_row7_col5 {
#   background-color: #d7ee8a;
#   color: #000000;
# }
# #T_15ea9_row7_col8 {
#   background-color: #c9e881;
#   color: #000000;
# }
# #T_15ea9_row7_col9 {
#   background-color: #e9f6a1;
#   color: #000000;
# }
# #T_15ea9_row8_col1 {
#   background-color: #f57547;
#   color: #f1f1f1;
# }
# #T_15ea9_row8_col2 {
#   background-color: #fffebe;
#   color: #000000;
# }
# #T_15ea9_row8_col3 {
#   background-color: #feffbe;
#   color: #000000;
# }
# #T_15ea9_row8_col4 {
#   background-color: #fec877;
#   color: #000000;
# }
# #T_15ea9_row8_col5 {
#   background-color: #c7e77f;
#   color: #000000;
# }
# #T_15ea9_row8_col8 {
#   background-color: #a5d86a;
#   color: #000000;
# }
# #T_15ea9_row9_col1 {
#   background-color: #f57245;
#   color: #f1f1f1;
# }
# #T_15ea9_row9_col2 {
#   background-color: #fdbb6c;
#   color: #000000;
# }
# #T_15ea9_row9_col3 {
#   background-color: #fdb163;
#   color: #000000;
# }
# #T_15ea9_row9_col5 {
#   background-color: #e6f59d;
#   color: #000000;
# }
# #T_15ea9_row9_col6, #T_15ea9_row9_col7 {
#   background-color: #249d53;
#   color: #f1f1f1;
# }
# #T_15ea9_row9_col8 {
#   background-color: #d1ec86;
#   color: #000000;
# }
# #T_15ea9_row9_col9 {
#   background-color: #f1f9ac;
#   color: #000000;
# }
# #T_15ea9_row10_col5 {
#   background-color: #feea9b;
#   color: #000000;
# }
# #T_15ea9_row10_col9 {
#   background-color: #fa9b58;
#   color: #000000;
# }
# </style>
# <table id="T_15ea9">
#   <thead>
#     <tr>
#       <th class="index_name level0" >norm</th>
#       <th id="T_15ea9_level0_col0" class="col_heading level0 col0" colspan="2">None</th>
#       <th id="T_15ea9_level0_col2" class="col_heading level0 col2" colspan="2">['season']</th>
#       <th id="T_15ea9_level0_col4" class="col_heading level0 col4" colspan="2">['season', 'position']</th>
#       <th id="T_15ea9_level0_col6" class="col_heading level0 col6" colspan="2">['season', 'player_cluster']</th>
#       <th id="T_15ea9_level0_col8" class="col_heading level0 col8" colspan="2">['season', 'team_cluster']</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >ma</th>
#       <th id="T_15ea9_level1_col0" class="col_heading level1 col0" >True</th>
#       <th id="T_15ea9_level1_col1" class="col_heading level1 col1" >False</th>
#       <th id="T_15ea9_level1_col2" class="col_heading level1 col2" >True</th>
#       <th id="T_15ea9_level1_col3" class="col_heading level1 col3" >False</th>
#       <th id="T_15ea9_level1_col4" class="col_heading level1 col4" >True</th>
#       <th id="T_15ea9_level1_col5" class="col_heading level1 col5" >False</th>
#       <th id="T_15ea9_level1_col6" class="col_heading level1 col6" >True</th>
#       <th id="T_15ea9_level1_col7" class="col_heading level1 col7" >False</th>
#       <th id="T_15ea9_level1_col8" class="col_heading level1 col8" >True</th>
#       <th id="T_15ea9_level1_col9" class="col_heading level1 col9" >False</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_15ea9_level0_row0" class="row_heading level0 row0" >Decision tree</th>
#       <td id="T_15ea9_row0_col0" class="data row0 col0" >45.6</td>
#       <td id="T_15ea9_row0_col1" class="data row0 col1" >46.5</td>
#       <td id="T_15ea9_row0_col2" class="data row0 col2" >45.7</td>
#       <td id="T_15ea9_row0_col3" class="data row0 col3" >45.3</td>
#       <td id="T_15ea9_row0_col4" class="data row0 col4" >46.9</td>
#       <td id="T_15ea9_row0_col5" class="data row0 col5" >50.0</td>
#       <td id="T_15ea9_row0_col6" class="data row0 col6" >49.2</td>
#       <td id="T_15ea9_row0_col7" class="data row0 col7" >49.6</td>
#       <td id="T_15ea9_row0_col8" class="data row0 col8" >47.9</td>
#       <td id="T_15ea9_row0_col9" class="data row0 col9" >46.3</td>
#     </tr>
#     <tr>
#       <th id="T_15ea9_level0_row1" class="row_heading level0 row1" >Xgboost</th>
#       <td id="T_15ea9_row1_col0" class="data row1 col0" >41
# STD of MAE scores
# <style type="text/css">
# #T_c4c6e_row0_col0 {
#   background-color: #108647;
#   color: #f1f1f1;
# }
# #T_c4c6e_row0_col1 {
#   background-color: #d42d27;
#   color: #f1f1f1;
# }
# #T_c4c6e_row0_col2 {
#   background-color: #f7844e;
#   color: #f1f1f1;
# }
# #T_c4c6e_row0_col3 {
#   background-color: #fed884;
#   color: #000000;
# }
# #T_c4c6e_row0_col4 {
#   background-color: #f8864f;
#   color: #f1f1f1;
# }
# #T_c4c6e_row0_col5, #T_c4c6e_row3_col0 {
#   background-color: #097940;
#   color: #f1f1f1;
# }
# #T_c4c6e_row0_col6, #T_c4c6e_row0_col7, #T_c4c6e_row1_col6, #T_c4c6e_row1_col7, #T_c4c6e_row2_col6, #T_c4c6e_row2_col7, #T_c4c6e_row3_col2, #T_c4c6e_row3_col3, #T_c4c6e_row3_col4, #T_c4c6e_row3_col6, #T_c4c6e_row3_col7, #T_c4c6e_row3_col8, #T_c4c6e_row4_col0, #T_c4c6e_row4_col1, #T_c4c6e_row4_col5, #T_c4c6e_row4_col7, #T_c4c6e_row5_col6, #T_c4c6e_row5_col7, #T_c4c6e_row5_col9, #T_c4c6e_row6_col6, #T_c4c6e_row6_col7, #T_c4c6e_row7_col6, #T_c4c6e_row7_col7, #T_c4c6e_row8_col6, #T_c4c6e_row8_col7 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_c4c6e_row0_col8 {
#   background-color: #fdc372;
#   color: #000000;
# }
# #T_c4c6e_row0_col9 {
#   background-color: #15904c;
#   color: #f1f1f1;
# }
# #T_c4c6e_row1_col0 {
#   background-color: #06733d;
#   color: #f1f1f1;
# }
# #T_c4c6e_row1_col1 {
#   background-color: #45ad5b;
#   color: #f1f1f1;
# }
# #T_c4c6e_row1_col2 {
#   background-color: #73c264;
#   color: #000000;
# }
# #T_c4c6e_row1_col3 {
#   background-color: #87cb67;
#   color: #000000;
# }
# #T_c4c6e_row1_col4, #T_c4c6e_row6_col9 {
#   background-color: #fff2aa;
#   color: #000000;
# }
# #T_c4c6e_row1_col5 {
#   background-color: #abdb6d;
#   color: #000000;
# }
# #T_c4c6e_row1_col8, #T_c4c6e_row2_col9 {
#   background-color: #16914d;
#   color: #f1f1f1;
# }
# #T_c4c6e_row1_col9, #T_c4c6e_row2_col2, #T_c4c6e_row4_col3 {
#   background-color: #afdd70;
#   color: #000000;
# }
# #T_c4c6e_row2_col0 {
#   background-color: #08773f;
#   color: #f1f1f1;
# }
# #T_c4c6e_row2_col1, #T_c4c6e_row4_col9 {
#   background-color: #42ac5a;
#   color: #f1f1f1;
# }
# #T_c4c6e_row2_col3 {
#   background-color: #ebf7a3;
#   color: #000000;
# }
# #T_c4c6e_row2_col4 {
#   background-color: #9bd469;
#   color: #000000;
# }
# #T_c4c6e_row2_col5 {
#   background-color: #05713c;
#   color: #f1f1f1;
# }
# #T_c4c6e_row2_col8 {
#   background-color: #a5d86a;
#   color: #000000;
# }
# #T_c4c6e_row3_col1 {
#   background-color: #af0926;
#   color: #f1f1f1;
# }
# #T_c4c6e_row3_col5 {
#   background-color: #9dd569;
#   color: #000000;
# }
# #T_c4c6e_row3_col9 {
#   background-color: #fff7b2;
#   color: #000000;
# }
# #T_c4c6e_row4_col2 {
#   background-color: #7ac665;
#   color: #000000;
# }
# #T_c4c6e_row4_col4 {
#   background-color: #c9e881;
#   color: #000000;
# }
# #T_c4c6e_row4_col6 {
#   background-color: #026c39;
#   color: #f1f1f1;
# }
# #T_c4c6e_row4_col8 {
#   background-color: #3ca959;
#   color: #f1f1f1;
# }
# #T_c4c6e_row5_col0, #T_c4c6e_row9_col1, #T_c4c6e_row9_col2, #T_c4c6e_row9_col3, #T_c4c6e_row9_col4, #T_c4c6e_row9_col5, #T_c4c6e_row9_col8, #T_c4c6e_row9_col9, #T_c4c6e_row10_col6, #T_c4c6e_row10_col7 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_c4c6e_row5_col1 {
#   background-color: #fdb567;
#   color: #000000;
# }
# #T_c4c6e_row5_col2 {
#   background-color: #a7d96b;
#   color: #000000;
# }
# #T_c4c6e_row5_col3 {
#   background-color: #b3df72;
#   color: #000000;
# }
# #T_c4c6e_row5_col4 {
#   background-color: #a2d76a;
#   color: #000000;
# }
# #T_c4c6e_row5_col5 {
#   background-color: #b1de71;
#   color: #000000;
# }
# #T_c4c6e_row5_col8 {
#   background-color: #016a38;
#   color: #f1f1f1;
# }
# #T_c4c6e_row6_col0 {
#   background-color: #118848;
#   color: #f1f1f1;
# }
# #T_c4c6e_row6_col1 {
#   background-color: #fff8b4;
#   color: #000000;
# }
# #T_c4c6e_row6_col2 {
#   background-color: #fff0a6;
#   color: #000000;
# }
# #T_c4c6e_row6_col3 {
#   background-color: #feeda1;
#   color: #000000;
# }
# #T_c4c6e_row6_col4 {
#   background-color: #f2faae;
#   color: #000000;
# }
# #T_c4c6e_row6_col5 {
#   background-color: #70c164;
#   color: #000000;
# }
# #T_c4c6e_row6_col8, #T_c4c6e_row7_col9 {
#   background-color: #fffebe;
#   color: #000000;
# }
# #T_c4c6e_row7_col0 {
#   background-color: #0d8044;
#   color: #f1f1f1;
# }
# #T_c4c6e_row7_col1 {
#   background-color: #d3ec87;
#   color: #000000;
# }
# #T_c4c6e_row7_col2 {
#   background-color: #fee797;
#   color: #000000;
# }
# #T_c4c6e_row7_col3 {
#   background-color: #fee593;
#   color: #000000;
# }
# #T_c4c6e_row7_col4 {
#   background-color: #feea9b;
#   color: #000000;
# }
# #T_c4c6e_row7_col5 {
#   background-color: #c7e77f;
#   color: #000000;
# }
# #T_c4c6e_row7_col8 {
#   background-color: #eff8aa;
#   color: #000000;
# }
# #T_c4c6e_row8_col0 {
#   background-color: #249d53;
#   color: #f1f1f1;
# }
# #T_c4c6e_row8_col1 {
#   background-color: #ce2827;
#   color: #f1f1f1;
# }
# #T_c4c6e_row8_col2, #T_c4c6e_row8_col8 {
#   background-color: #dc3b2c;
#   color: #f1f1f1;
# }
# #T_c4c6e_row8_col3 {
#   background-color: #db382b;
#   color: #f1f1f1;
# }
# #T_c4c6e_row8_col4 {
#   background-color: #e75337;
#   color: #f1f1f1;
# }
# #T_c4c6e_row8_col5 {
#   background-color: #f7814c;
#   color: #f1f1f1;
# }
# #T_c4c6e_row8_col9 {
#   background-color: #da362a;
#   color: #f1f1f1;
# }
# #T_c4c6e_row9_col0 {
#   background-color: #2aa054;
#   color: #f1f1f1;
# }
# #T_c4c6e_row9_col6, #T_c4c6e_row9_col7 {
#   background-color: #66bd63;
#   color: #f1f1f1;
# }
# #T_c4c6e_row10_col0 {
#   background-color: #1b9950;
#   color: #f1f1f1;
# }
# #T_c4c6e_row10_col1 {
#   background-color: #ef633f;
#   color: #f1f1f1;
# }
# #T_c4c6e_row10_col2 {
#   background-color: #fba05b;
#   color: #000000;
# }
# #T_c4c6e_row10_col3 {
#   background-color: #fb9d59;
#   color: #000000;
# }
# #T_c4c6e_row10_col4, #T_c4c6e_row10_col9 {
#   background-color: #f98e52;
#   color: #f1f1f1;
# }
# #T_c4c6e_row10_col5 {
#   background-color: #fed07e;
#   color: #000000;
# }
# #T_c4c6e_row10_col8 {
#   background-color: #fa9b58;
#   color: #000000;
# }
# </style>
# <table id="T_c4c6e">
#   <thead>
#     <tr>
#       <th class="index_name level0" >norm</th>
#       <th id="T_c4c6e_level0_col0" class="col_heading level0 col0" colspan="2">None</th>
#       <th id="T_c4c6e_level0_col2" class="col_heading level0 col2" colspan="2">['season']</th>
#       <th id="T_c4c6e_level0_col4" class="col_heading level0 col4" colspan="2">['season', 'position']</th>
#       <th id="T_c4c6e_level0_col6" class="col_heading level0 col6" colspan="2">['season', 'player_cluster']</th>
#       <th id="T_c4c6e_level0_col8" class="col_heading level0 col8" colspan="2">['season', 'team_cluster']</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >ma</th>
#       <th id="T_c4c6e_level1_col0" class="col_heading level1 col0" >True</th>
#       <th id="T_c4c6e_level1_col1" class="col_heading level1 col1" >False</th>
#       <th id="T_c4c6e_level1_col2" class="col_heading level1 col2" >True</th>
#       <th id="T_c4c6e_level1_col3" class="col_heading level1 col3" >False</th>
#       <th id="T_c4c6e_level1_col4" class="col_heading level1 col4" >True</th>
#       <th id="T_c4c6e_level1_col5" class="col_heading level1 col5" >False</th>
#       <th id="T_c4c6e_level1_col6" class="col_heading level1 col6" >True</th>
#       <th id="T_c4c6e_level1_col7" class="col_heading level1 col7" >False</th>
#       <th id="T_c4c6e_level1_col8" class="col_heading level1 col8" >True</th>
#       <th id="T_c4c6e_level1_col9" class="col_heading level1 col9" >False</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c4c6e_level0_row0" class="row_heading level0 row0" >Decision tree</th>
#       <td id="T_c4c6e_row0_col0" class="data row0 col0" >2.7</td>
#       <td id="T_c4c6e_row0_col1" class="data row0 col1" >3.5</td>
#       <td id="T_c4c6e_row0_col2" class="data row0 col2" >3.1</td>
#       <td id="T_c4c6e_row0_col3" class="data row0 col3" >2.7</td>
#       <td id="T_c4c6e_row0_col4" class="data row0 col4" >3.4</td>
#       <td id="T_c4c6e_row0_col5" class="data row0 col5" >2.1</td>
#       <td id="T_c4c6e_row0_col6" class="data row0 col6" >3.9</td>
#       <td id="T_c4c6e_row0_col7" class="data row0 col7" >2.5</td>
#       <td id="T_c4c6e_row0_col8" class="data row0 col8" >3.1</td>
#       <td id="T_c4c6e_row0_col9" class="data row0 col9" >1.3</td>
#     </tr>
#     <tr>
#       <th id="T_c4c6e_level0_row1" class="row_heading level0 row1" >Xgboost</th>
#       <td id="T_c4c6e_row1_col0" class="data row1 col0" >2.0</td>

# %%
# best model: 
f1 = df_param.target == 'fantasy_points_ppr'
f2 = df_param.ma == False
f3 = df_param.norm == 'None'

df_param[f1&f2&f3]['Linear model']
# Out:
# 1    {'alpha': 1, 'l1_ratio': 0.5}
# Name: Linear model, dtype: object

# %%
#####################
# PREDICTING
#####################
# 1) create datasets

# for training
x, y, m, s, df_out = get_datasets(df = df[df.season_len > 1], 
                          feat_target = 'fantasy_points_ppr', 
                          feat_norm = None, 
                          norm_shift = 1, 
                          flg_ma = False)
print(x.shape)

# for predictions
x1, y1, m1, s1, df_out1 = get_datasets(df = df,   # change here
                          feat_target = 'fantasy_points_ppr', 
                          feat_norm = None, 
                          norm_shift = 0,         # change here
                          flg_ma = False)
print(x1.shape)


# 2) train model with the best params
from sklearn.linear_model import ElasticNet
params = {
    'alpha': 1, 
    'l1_ratio': 0.5
}
clf = ElasticNet(**params)
clf.fit(x, y)

# 3) make predictions
pred = clf.predict(x1)
df_out1['pred'] = (pred * s1 + m1).values
df_out1 = df_out1[['display_name','pred']]


# 4) add Fullback position predictions and save to file
df_out2 = pd.read_csv('data/output_add1.csv')
df_out1.columns = df_out2.columns

df_out = pd.concat([df_out1, df_out2])
df_out.to_csv('data/output_nfl.csv')
print(df_out.shape)
df_out.sort_values('Projected fantasy points scored PPR for 2023', ascending = False)[:10]
# Out:
# (444, 9)
# (560, 9)
# (572, 2)
#            Player Name  Projected fantasy points scored PPR for 2023
# 1066   Patrick Mahomes                                        365.05
# 1445        Josh Allen                                        359.20
# 1120       Cooper Kupp                                        343.05
# 972     Deshaun Watson                                        322.88
# 1856    Justin Herbert                                        290.39
# 1015     Austin Ekeler                                        281.96
# 7            Tom Brady                                        278.42
# 388      Davante Adams                                        267.73
# 1776   Jonathan Taylor                                        265.53
# 1836  Justin Jefferson                                        254.48

# %%
# formula of the linear model:
c = clf.intercept_
f'{c:.2f} + ' + ' + '.join([f'{b:.3f}*{a}' for a,b in zip(x.columns,clf.coef_)])
# Out:
# '-121.72 + 0.932*static_height_cm + -0.388*static_weight_kg + -0.000*static_bmi_calc + 0.639*lag1 + 0.078*lag2 + 0.050*lag3 + 0.181*lag4 + -0.052*lag5 + -0.211*lag6'

# %% [markdown]
# ### check

# %%
(-121.72 + 0.932*x1.static_height_cm - 0.388*x1.static_weight_kg + 0.639*x1.lag1 + 0.078*x1.lag2 + 0.05*x1.lag3 + 0.181*x1.lag4 - 0.052*x1.lag5 - 0.211*x1.lag6)[:5]
# Out:
# 7    278.31
# 15   240.08
# 23    36.77
# 31   176.76
# 39     7.59
# dtype: float64

# %%
clf.predict(x1)[:5]
# Out:
# array([278.13807745, 239.8787224 ,  36.65319858, 176.58283338,
#          7.45200599])
